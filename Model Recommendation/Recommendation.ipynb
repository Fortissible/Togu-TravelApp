# %%
# Untuk pengolahan data
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# Untuk mengupload file
import os
import io

# %%
import os
from google.colab import files

rating1 = files.upload()
place1 = files.upload()
user1 = files.upload()
# Out:
#      <input type="file" id="files-f4ed93dc-63d1-4c6b-9b11-3f042f3b0452" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4ed93dc-63d1-4c6b-9b11-3f042f3b0452">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tourism_rating.csv to tourism_rating.csv
#      <input type="file" id="files-a5fdf7fb-6542-461e-889e-8bac0b6722df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5fdf7fb-6542-461e-889e-8bac0b6722df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tourism_with_id.csv to tourism_with_id.csv
#      <input type="file" id="files-3b1bc95d-9ee5-4aa2-8335-7d2a33667d01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b1bc95d-9ee5-4aa2-8335-7d2a33667d01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving user.csv to user.csv

# %%
rating = pd.read_csv(io.StringIO(rating1['tourism_rating.csv'].decode('utf-8')))
print(rating)
# Out:
#       User_Id  Place_Id  Place_Ratings
# 0           1       179              3
# 1           1       344              2
# 2           1         5              5
# 3           1       373              3
# 4           1       101              4
# ...       ...       ...            ...
# 9995      300       425              2
# 9996      300        64              4
# 9997      300       311              3
# 9998      300       279              4
# 9999      300       163              2
#
# [10000 rows x 3 columns]

# %%
place = pd.read_csv(io.StringIO(place1['tourism_with_id.csv'].decode('utf-8')))
print(place)
# Out:
#      Place_Id                                 Place_Name  \
# 0           1                           Monumen Nasional
# 1           2                                   Kota Tua
# 2           3                              Dunia Fantasi
# 3           4          Taman Mini Indonesia Indah (TMII)
# 4           5                   Atlantis Water Adventure
# ..        ...                                        ...
# 432       433                        Museum Mpu Tantular
# 433       434                              Taman Bungkul
# 434       435           Taman Air Mancur Menari Kenjeran
# 435       436               Taman Flora Bratang Surabaya
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya
#
#                                            Description       Category  \
# 0    Monumen Nasional atau yang populer disingkat d...         Budaya
# 1    Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya
# 2    Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan
# 3    Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan
# 4    Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan
# ..                                                 ...            ...
# 432  Museum Negeri Mpu Tantular adalah sebuah museu...         Budaya
# 433  Taman Bungkul adalah taman wisata kota yang te...  Taman Hiburan
# 434  Air mancur menari atau dancing fountain juga a...  Taman Hiburan
# 435  Taman Flora adalah salah satu taman kota di Su...  Taman Hiburan
# 436  Gereja Katolik Kelahiran Santa Perawan Maria m...  Tempat Ibadah
#
#          City   Price  Rating  Time_Minutes  \
# 0     Jakarta   20000     4.6          15.0
# 1     Jakarta       0     4.6          90.0
# 2     Jakarta  270000     4.6         360.0
# 3     Jakarta   10000     4.5           NaN
# 4     Jakarta   94000     4.5          60.0
# ..        ...     ...     ...           ...
# 432  Surabaya    2000     4.4          45.0
# 433  Surabaya       0     4.6           NaN
# 434  Surabaya       0     4.4          45.0
# 435  Surabaya       0     4.6           NaN
# 436  Surabaya   10000     4.8           NaN
#
#                                           Coordinate       Lat        Long  \
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 432          {'lat': -7.4338593, 'lng': 112.7199058} -7.433859  112.719906
# 433  {'lat': -7.291346799999999, 'lng': 112.7398218} -7.291347  112.739822
# 434          {'lat': -7.2752955, 'lng': 112.7549381} -7.275296  112.754938
# 435  {'lat': -7.294330299999999, 'lng': 112.7617534} -7.294330  112.761753
# 436          {'lat': -7.2420758, 'lng': 112.7368158} -7.242076  112.736816
#
#      Unnamed: 11  Unnamed: 12
# 0            NaN            1
# 1            NaN            2
# 2            NaN            3
# 3            NaN            4
# 4            NaN            5
# ..           ...          ...
# 432          NaN          433
# 433          NaN          434
# 434          NaN          435
# 435          NaN          436
# 436          NaN          437
#
# [437 rows x 13 columns]

# %%
user = pd.read_csv(io.StringIO(user1['user.csv'].decode('utf-8')))
print(user)
# Out:
#      User_Id                     Location  Age
# 0          1        Semarang, Jawa Tengah   20
# 1          2           Bekasi, Jawa Barat   21
# 2          3          Cirebon, Jawa Barat   23
# 3          4           Bekasi, Jawa Barat   21
# 4          5    Lampung, Sumatera Selatan   20
# ..       ...                          ...  ...
# 295      296    Lampung, Sumatera Selatan   31
# 296      297  Palembang, Sumatera Selatan   39
# 297      298            Bogor, Jawa Barat   38
# 298      299          Sragen, Jawa Tengah   27
# 299      300         Ponorogo, Jawa Timur   26
#
# [300 rows x 3 columns]

# %%
place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long  Unnamed: 11  Unnamed: 12
# 0 -6.175392  106.827153          NaN            1
# 1 -6.137645  106.817125          NaN            2

# %%
place = place.drop(['Unnamed: 11','Unnamed: 12'],axis=1)
place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long
# 0 -6.175392  106.827153
# 1 -6.137645  106.817125

# %%
place = place[place['City']=='Bandung']
place.head(2)
# Out:
#      Place_Id              Place_Name  \
# 210       211  GunungTangkuban perahu
# 211       212             Jalan Braga
#
#                                            Description    Category     City  \
# 210  Gunung Tangkuban Parahu adalah salah satu gunu...  Cagar Alam  Bandung
# 211  Jalan Braga adalah nama sebuah jalan utama di ...      Budaya  Bandung
#
#      Price  Rating  Time_Minutes  \
# 210  30000     4.5           NaN
# 211      0     4.7           NaN
#
#                                           Coordinate       Lat        Long
# 210  {'lat': -6.759637700000001, 'lng': 107.6097807} -6.759638  107.609781
# 211          {'lat': -6.9150534, 'lng': 107.6089842} -6.915053  107.608984

# %%
place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 210 to 333
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Place_Id      124 non-null    int64
#  1   Place_Name    124 non-null    object
#  2   Description   124 non-null    object
#  3   Category      124 non-null    object
#  4   City          124 non-null    object
#  5   Price         124 non-null    int64
#  6   Rating        124 non-null    float64
#  7   Time_Minutes  50 non-null     float64
#  8   Coordinate    124 non-null    object
#  9   Lat           124 non-null    float64
#  10  Long          124 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 11.6+ KB

# %%
place = place.drop('Time_Minutes', axis=1)

# %%
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
# Merubah data rating (hanya dari Kota Bandung)

rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        9       211              3
# 1       26       211              2
# 2       40       211              3
# 3       40       211              2
# 4       70       211              5

# %%
rating.shape
# Out:
# (2842, 3)

# %%
# Melihat data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user (hanya yang pernah mengunjungi Kota Bandung)

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').drop_duplicates().sort_values('User_Id')
user.head()
# Out:
#       User_Id                   Location  Age
# 260         1      Semarang, Jawa Tengah   20
# 1178        2         Bekasi, Jawa Barat   21
# 279         3        Cirebon, Jawa Barat   23
# 418         4         Bekasi, Jawa Barat   21
# 1655        5  Lampung, Sumatera Selatan   20

# %%
user.shape
# Out:
# (300, 3)

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10 = pd.merge(top_10, place[['Place_Id','Place_Name']], how='left', left_on='index', right_on='Place_Id')

# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8,5))
sns.barplot('Place_Id_x', 'Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Jumlah Rating')
plt.xlabel('Nama Lokasi')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata di Kota Bandung

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata di Kota Bandung', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata di Kota Bandung', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %%
# Membaca dataset untuk dilakukan encoding
 
df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        9       211              3
# 1       26       211              2
# 2       40       211              3
# 3       40       211              2
# 4       70       211              5

# %%
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %%
# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)
 
# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)
 
# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])
 
print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 124, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42).iloc[:1000,:]
df
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 415       245       228            2.0    56     17
# 2233       44       309            3.0    45     98
# 1149      194       260            5.0   205     49
# 1113      151       259            3.0    52     48
# 1225       93       264            2.0   229     53
# ...       ...       ...            ...   ...    ...
# 969       268       252            2.0   284     41
# 2789      175       332            5.0   295    121
# 1954      295       296            4.0   289     85
# 629       190       238            4.0   156     27
# 2605      266       324            4.0   278    113
#
# [1000 rows x 5 columns]

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x,y,train_size=.8, random_state=123)

# %%
x_train[:,0].shape
# Out:
# (800,)

# %%
# creating book embedding path
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense
from tensorflow.keras import Model
tourism_input = Input(shape=[1], name="Tourism-Input")
tourism_embedding = Embedding(num_place+1, 50, name="Tourism-Embedding")(tourism_input)
tourism_vec = Flatten(name="Flatten-Books")(tourism_embedding)
# creating user embedding path
user_input = Input(shape=[1], name="User-Input")
user_embedding = Embedding(num_users+1, 50, name="User-Embedding")(user_input)
user_vec = Flatten(name="Flatten-Users")(user_embedding)
# concatenate features
conc = Concatenate()([tourism_vec, user_vec])
# add fully-connected-layers
fc1 = Dense(32, activation='relu')(conc)
fc2 = Dense(32, activation='relu')(fc1)
#fc3 = Dense(32, activation='relu')(fc2)
out = Dense(1, activation='sigmoid')(fc2)
# Create model and compile it
model2 = Model([user_input, tourism_input], out)
model2.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(0.0005),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)
history = model2.fit([x_train[:,0],x_train[:,1]], y_train,validation_data = ([x_val[:,0], x_val[:,1]], y_val), epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 4s 30ms/step - loss: 0.6933 - root_mean_squared_error: 0.3497 - val_loss: 0.6931 - val_root_mean_squared_error: 0.3368
# Epoch 2/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.6910 - root_mean_squared_error: 0.3480 - val_loss: 0.6928 - val_root_mean_squared_error: 0.3366
# Epoch 3/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6886 - root_mean_squared_error: 0.3463 - val_loss: 0.6927 - val_root_mean_squared_error: 0.3365
# Epoch 4/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6850 - root_mean_squared_error: 0.3437 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3362
# Epoch 5/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6786 - root_mean_squared_error: 0.3390 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3361
# Epoch 6/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6671 - root_mean_squared_error: 0.3305 - val_loss: 0.6930 - val_root_mean_squared_error: 0.3367
# Epoch 7/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6478 - root_mean_squared_error: 0.3158 - val_loss: 0.7018 - val_root_mean_squared_error: 0.3429
# Epoch 8/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6201 - root_mean_squared_error: 0.2941 - val_loss: 0.7258 - val_root_mean_squared_error: 0.3584
# Epoch 9/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5933 - root_mean_squared_error: 0.2730 - val_loss: 0.7662 - val_root_mean_squared_error: 0.3801
# Epoch 10/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.5727 - root_mean_squared_error: 0.2566 - val_loss: 0.8007 - val_root_mean_squared_error: 0.3947
# Epoch 11/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.5585 - root_mean_squared_error: 0.2450 - val_loss: 0.8318 - val_root_mean_squared_error: 0.4061
# Epoch 12/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5477 - root_mean_squared_error: 0.2361 - val_loss: 0.8514 - val_root_mean_squared_error: 0.4121
# Epoch 13/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5386 - root_mean_squared_error: 0.2281 - val_loss: 0.8757 - val_root_mean_squared_error: 0.4189
# Epoch 14/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.5296 - root_mean_squared_error: 0.2203 - val_loss: 0.9007 - val_root_mean_squared_error: 0.4254
# Epoch 15/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.5218 - root_mean_squared_error: 0.2134 - val_loss: 0.9147 - val_root_mean_squared_error: 0.4279
# Epoch 16/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5129 - root_mean_squared_error: 0.2051 - val_loss: 0.9385 - val_root_mean_squared_error: 0.4330
# Epoch 17/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5056 - root_mean_squared_error: 0.1982 - val_loss: 0.9594 - val_root_mean_squared_error: 0.4367
# Epoch 18/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4970 - root_mean_squared_error: 0.1900 - val_loss: 0.9789 - val_root_mean_squared_error: 0.4395
# Epoch 19/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4896 - root_mean_squared_error: 0.1826 - val_loss: 1.0039 - val_root_mean_squared_error: 0.4444
# Epoch 20/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4809 - root_mean_squared_error: 0.1733 - val_loss: 1.0160 - val_root_mean_squared_error: 0.4456
# Epoch 21/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4740 - root_mean_squared_error: 0.1659 - val_loss: 1.0514 - val_root_mean_squared_error: 0.4509
# Epoch 22/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4652 - root_mean_squared_error: 0.1564 - val_loss: 1.0632 - val_root_mean_squared_error: 0.4503
# Epoch 23/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4584 - root_mean_squared_error: 0.1481 - val_loss: 1.0803 - val_root_mean_squared_error: 0.4521
# Epoch 24/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4506 - root_mean_squared_error: 0.1388 - val_loss: 1.1067 - val_root_mean_squared_error: 0.4551
# Epoch 25/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4436 - root_mean_squared_error: 0.1303 - val_loss: 1.1303 - val_root_mean_squared_error: 0.4569
# Epoch 26/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4366 - root_mean_squared_error: 0.1209 - val_loss: 1.1514 - val_root_mean_squared_error: 0.4589
# Epoch 27/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4303 - root_mean_squared_error: 0.1123 - val_loss: 1.1722 - val_root_mean_squared_error: 0.4599
# Epoch 28/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4244 - root_mean_squared_error: 0.1041 - val_loss: 1.1949 - val_root_mean_squared_error: 0.4624
# Epoch 29/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4192 - root_mean_squared_error: 0.0969 - val_loss: 1.2157 - val_root_mean_squared_error: 0.4631
# Epoch 30/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4142 - root_mean_squared_error: 0.0895 - val_loss: 1.2403 - val_root_mean_squared_error: 0.4663
# Epoch 31/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4103 - root_mean_squared_error: 0.0844 - val_loss: 1.2587 - val_root_mean_squared_error: 0.4657
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4057 - root_mean_squared_error: 0.0771 - val_loss: 1.2805 - val_root_mean_squared_error: 0.4687
# Epoch 33/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4021 - root_mean_squared_error: 0.0715 - val_loss: 1.3032 - val_root_mean_squared_error: 0.4692
# Epoch 34/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3997 - root_mean_squared_error: 0.0689 - val_loss: 1.3158 - val_root_mean_squared_error: 0.4704
# Epoch 35/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3972 - root_mean_squared_error: 0.0651 - val_loss: 1.3500 - val_root_mean_squared_error: 0.4734
# Epoch 36/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3949 - root_mean_squared_error: 0.0613 - val_loss: 1.3688 - val_root_mean_squared_error: 0.4756
# Epoch 37/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3928 - root_mean_squared_error: 0.0590 - val_loss: 1.3864 - val_root_mean_squared_error: 0.4745
# Epoch 38/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3912 - root_mean_squared_error: 0.0569 - val_loss: 1.4043 - val_root_mean_squared_error: 0.4769
# Epoch 39/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3902 - root_mean_squared_error: 0.0569 - val_loss: 1.4320 - val_root_mean_squared_error: 0.4786
# Epoch 40/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3887 - root_mean_squared_error: 0.0543 - val_loss: 1.4462 - val_root_mean_squared_error: 0.4815
# Epoch 41/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3885 - root_mean_squared_error: 0.0558 - val_loss: 1.4710 - val_root_mean_squared_error: 0.4809
# Epoch 42/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3880 - root_mean_squared_error: 0.0563 - val_loss: 1.4709 - val_root_mean_squared_error: 0.4821
# Epoch 43/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3871 - root_mean_squared_error: 0.0549 - val_loss: 1.5049 - val_root_mean_squared_error: 0.4843
# Epoch 44/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3866 - root_mean_squared_error: 0.0546 - val_loss: 1.4894 - val_root_mean_squared_error: 0.4809
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3859 - root_mean_squared_error: 0.0540 - val_loss: 1.5330 - val_root_mean_squared_error: 0.4869
# Epoch 46/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3853 - root_mean_squared_error: 0.0526 - val_loss: 1.5258 - val_root_mean_squared_error: 0.4851
# Epoch 47/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3849 - root_mean_squared_error: 0.0542 - val_loss: 1.5456 - val_root_mean_squared_error: 0.4848
# Epoch 48/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3845 - root_mean_squared_error: 0.0523 - val_loss: 1.5482 - val_root_mean_squared_error: 0.4855
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3839 - root_mean_squared_error: 0.0517 - val_loss: 1.5667 - val_root_mean_squared_error: 0.4880
# Epoch 50/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3833 - root_mean_squared_error: 0.0504 - val_loss: 1.5690 - val_root_mean_squared_error: 0.4871
# Epoch 51/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3832 - root_mean_squared_error: 0.0514 - val_loss: 1.5856 - val_root_mean_squared_error: 0.4876
# Epoch 52/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3818 - root_mean_squared_error: 0.0460 - val_loss: 1.5887 - val_root_mean_squared_error: 0.4875
# Epoch 53/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3814 - root_mean_squared_error: 0.0450 - val_loss: 1.6065 - val_root_mean_squared_error: 0.4891
# Epoch 54/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3813 - root_mean_squared_error: 0.0461 - val_loss: 1.6105 - val_root_mean_squared_error: 0.4889
# Epoch 55/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3810 - root_mean_squared_error: 0.0453 - val_loss: 1.6282 - val_root_mean_squared_error: 0.4900
# Epoch 56/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3813 - root_mean_squared_error: 0.0475 - val_loss: 1.6278 - val_root_mean_squared_error: 0.4902
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3819 - root_mean_squared_error: 0.0510 - val_loss: 1.6460 - val_root_mean_squared_error: 0.4917
# Epoch 58/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3822 - root_mean_squared_error: 0.0521 - val_loss: 1.6420 - val_root_mean_squared_error: 0.4912
# Epoch 59/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3824 - root_mean_squared_error: 0.0541 - val_loss: 1.6538 - val_root_mean_squared_error: 0.4913
# Epoch 60/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3823 - root_mean_squared_error: 0.0535 - val_loss: 1.6510 - val_root_mean_squared_error: 0.4914
# Epoch 61/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3824 - root_mean_squared_error: 0.0543 - val_loss: 1.6574 - val_root_mean_squared_error: 0.4908
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3819 - root_mean_squared_error: 0.0526 - val_loss: 1.6613 - val_root_mean_squared_error: 0.4919
# Epoch 63/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3822 - root_mean_squared_error: 0.0538 - val_loss: 1.6677 - val_root_mean_squared_error: 0.4907
# Epoch 64/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3820 - root_mean_squared_error: 0.0534 - val_loss: 1.6595 - val_root_mean_squared_error: 0.4929
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3816 - root_mean_squared_error: 0.0523 - val_loss: 1.6721 - val_root_mean_squared_error: 0.4925
# Epoch 66/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3807 - root_mean_squared_error: 0.0493 - val_loss: 1.6587 - val_root_mean_squared_error: 0.4898
# Epoch 67/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3807 - root_mean_squared_error: 0.0499 - val_loss: 1.6745 - val_root_mean_squared_error: 0.4912
# Epoch 68/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3807 - root_mean_squared_error: 0.0495 - val_loss: 1.6643 - val_root_mean_squared_error: 0.4909
# Epoch 69/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3806 - root_mean_squared_error: 0.0494 - val_loss: 1.6868 - val_root_mean_squared_error: 0.4923
# Epoch 70/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3805 - root_mean_squared_error: 0.0491 - val_loss: 1.6613 - val_root_mean_squared_error: 0.4910
# Epoch 71/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3816 - root_mean_squared_error: 0.0544 - val_loss: 1.6985 - val_root_mean_squared_error: 0.4931
# Epoch 72/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3818 - root_mean_squared_error: 0.0546 - val_loss: 1.6707 - val_root_mean_squared_error: 0.4925
# Epoch 73/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3815 - root_mean_squared_error: 0.0540 - val_loss: 1.6843 - val_root_mean_squared_error: 0.4905
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3813 - root_mean_squared_error: 0.0528 - val_loss: 1.6791 - val_root_mean_squared_error: 0.4928
# Epoch 75/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3806 - root_mean_squared_error: 0.0502 - val_loss: 1.6906 - val_root_mean_squared_error: 0.4918
# Epoch 76/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3806 - root_mean_squared_error: 0.0506 - val_loss: 1.6634 - val_root_mean_squared_error: 0.4910
# Epoch 77/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3803 - root_mean_squared_error: 0.0496 - val_loss: 1.6931 - val_root_mean_squared_error: 0.4928
# Epoch 78/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3800 - root_mean_squared_error: 0.0486 - val_loss: 1.6764 - val_root_mean_squared_error: 0.4908
# Epoch 79/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3796 - root_mean_squared_error: 0.0470 - val_loss: 1.7035 - val_root_mean_squared_error: 0.4929
# Epoch 80/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3797 - root_mean_squared_error: 0.0476 - val_loss: 1.6872 - val_root_mean_squared_error: 0.4921
# Epoch 81/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3799 - root_mean_squared_error: 0.0487 - val_loss: 1.6905 - val_root_mean_squared_error: 0.4920
# Epoch 82/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3793 - root_mean_squared_error: 0.0459 - val_loss: 1.6907 - val_root_mean_squared_error: 0.4919
# Epoch 83/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3795 - root_mean_squared_error: 0.0470 - val_loss: 1.7077 - val_root_mean_squared_error: 0.4943
# Epoch 84/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3793 - root_mean_squared_error: 0.0468 - val_loss: 1.6986 - val_root_mean_squared_error: 0.4926
# Epoch 85/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3792 - root_mean_squared_error: 0.0463 - val_loss: 1.7147 - val_root_mean_squared_error: 0.4954
# Epoch 86/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3797 - root_mean_squared_error: 0.0482 - val_loss: 1.6962 - val_root_mean_squared_error: 0.4917
# Epoch 87/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3799 - root_mean_squared_error: 0.0499 - val_loss: 1.7158 - val_root_mean_squared_error: 0.4949
# Epoch 88/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3807 - root_mean_squared_error: 0.0529 - val_loss: 1.6965 - val_root_mean_squared_error: 0.4929
# Epoch 89/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3800 - root_mean_squared_error: 0.0499 - val_loss: 1.7072 - val_root_mean_squared_error: 0.4934
# Epoch 90/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3800 - root_mean_squared_error: 0.0501 - val_loss: 1.6922 - val_root_mean_squared_error: 0.4921
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3799 - root_mean_squared_error: 0.0500 - val_loss: 1.7047 - val_root_mean_squared_error: 0.4932
# Epoch 92/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3799 - root_mean_squared_error: 0.0496 - val_loss: 1.7008 - val_root_mean_squared_error: 0.4921
# Epoch 93/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3792 - root_mean_squared_error: 0.0472 - val_loss: 1.6983 - val_root_mean_squared_error: 0.4914
# Epoch 94/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3791 - root_mean_squared_error: 0.0462 - val_loss: 1.7041 - val_root_mean_squared_error: 0.4925
# Epoch 95/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3787 - root_mean_squared_error: 0.0453 - val_loss: 1.7105 - val_root_mean_squared_error: 0.4934
# Epoch 96/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3783 - root_mean_squared_error: 0.0433 - val_loss: 1.7122 - val_root_mean_squared_error: 0.4934
# Epoch 97/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3787 - root_mean_squared_error: 0.0456 - val_loss: 1.7125 - val_root_mean_squared_error: 0.4922
# Epoch 98/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3789 - root_mean_squared_error: 0.0465 - val_loss: 1.7242 - val_root_mean_squared_error: 0.4943
# Epoch 99/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3789 - root_mean_squared_error: 0.0466 - val_loss: 1.7149 - val_root_mean_squared_error: 0.4919
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3786 - root_mean_squared_error: 0.0453 - val_loss: 1.7271 - val_root_mean_squared_error: 0.4949

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Tourism-Input (InputLayer)     [(None, 1)]          0           []
#
#  User-Input (InputLayer)        [(None, 1)]          0           []
#
#  Tourism-Embedding (Embedding)  (None, 1, 50)        6250        ['Tourism-Input[0][0]']
#
#  User-Embedding (Embedding)     (None, 1, 50)        15050       ['User-Input[0][0]']
#
#  Flatten-Books (Flatten)        (None, 50)           0           ['Tourism-Embedding[0][0]']
#
#  Flatten-Users (Flatten)        (None, 50)           0           ['User-Embedding[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 100)          0           ['Flatten-Books[0][0]',
#                                                                   'Flatten-Users[0][0]']
#
#  dense_3 (Dense)                (None, 32)           3232        ['concatenate_2[0][0]']
#
#  dense_4 (Dense)                (None, 32)           1056        ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 25,621
# Trainable params: 25,621
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_places, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_places = num_places
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( 
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) 
    self.places_embedding = layers.Embedding( 
        num_places,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.places_bias = layers.Embedding(num_places, 1) 
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) 
    user_bias = self.user_bias(inputs[:, 0]) 
    places_vector = self.places_embedding(inputs[:, 1]) 
    places_bias = self.places_bias(inputs[:, 1]) 
 
    dot_user_places = tf.tensordot(user_vector, places_vector, 2) 
 
    x = dot_user_places + user_bias + places_bias
    
    return tf.nn.sigmoid(x)

# %%
model = RecommenderNet(num_users, num_place, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.0004),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_root_mean_squared_error')<0.25):
      print('Lapor! Metriks validasi sudah sesuai harapan')
      self.model.stop_training = True

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    epochs = 100,
    validation_data = (x_val, y_val),
    callbacks = [myCallback()]
)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 13ms/step - loss: 0.7046 - root_mean_squared_error: 0.3573 - val_loss: 0.6974 - val_root_mean_squared_error: 0.3397
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7034 - root_mean_squared_error: 0.3558 - val_loss: 0.6974 - val_root_mean_squared_error: 0.3398
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7054 - root_mean_squared_error: 0.3578 - val_loss: 0.6968 - val_root_mean_squared_error: 0.3393
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7018 - root_mean_squared_error: 0.3554 - val_loss: 0.6957 - val_root_mean_squared_error: 0.3385
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7014 - root_mean_squared_error: 0.3551 - val_loss: 0.6951 - val_root_mean_squared_error: 0.3381
# Epoch 6/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.7016 - root_mean_squared_error: 0.3552 - val_loss: 0.6948 - val_root_mean_squared_error: 0.3379
# Epoch 7/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.7149 - root_mean_squared_error: 0.3635 - val_loss: 0.6940 - val_root_mean_squared_error: 0.3373
# Epoch 8/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7079 - root_mean_squared_error: 0.3592 - val_loss: 0.6937 - val_root_mean_squared_error: 0.3371
# Epoch 9/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7178 - root_mean_squared_error: 0.3658 - val_loss: 0.6940 - val_root_mean_squared_error: 0.3373
# Epoch 10/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6995 - root_mean_squared_error: 0.3538 - val_loss: 0.6940 - val_root_mean_squared_error: 0.3373
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6992 - root_mean_squared_error: 0.3534 - val_loss: 0.6939 - val_root_mean_squared_error: 0.3372
# Epoch 12/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7012 - root_mean_squared_error: 0.3547 - val_loss: 0.6937 - val_root_mean_squared_error: 0.3371
# Epoch 13/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7074 - root_mean_squared_error: 0.3586 - val_loss: 0.6935 - val_root_mean_squared_error: 0.3370
# Epoch 14/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6932 - root_mean_squared_error: 0.3494 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 15/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6952 - root_mean_squared_error: 0.3508 - val_loss: 0.6929 - val_root_mean_squared_error: 0.3365
# Epoch 16/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6892 - root_mean_squared_error: 0.3466 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3361
# Epoch 17/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6941 - root_mean_squared_error: 0.3501 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3359
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6947 - root_mean_squared_error: 0.3504 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3360
# Epoch 19/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6934 - root_mean_squared_error: 0.3494 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3362
# Epoch 20/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6838 - root_mean_squared_error: 0.3428 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 21/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6855 - root_mean_squared_error: 0.3439 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3359
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6883 - root_mean_squared_error: 0.3459 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 23/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6864 - root_mean_squared_error: 0.3445 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3358
# Epoch 24/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6865 - root_mean_squared_error: 0.3445 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3358
# Epoch 25/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6872 - root_mean_squared_error: 0.3451 - val_loss: 0.6918 - val_root_mean_squared_error: 0.3356
# Epoch 26/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6830 - root_mean_squared_error: 0.3422 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 27/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6799 - root_mean_squared_error: 0.3399 - val_loss: 0.6918 - val_root_mean_squared_error: 0.3357
# Epoch 28/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6809 - root_mean_squared_error: 0.3407 - val_loss: 0.6915 - val_root_mean_squared_error: 0.3354
# Epoch 29/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6817 - root_mean_squared_error: 0.3412 - val_loss: 0.6914 - val_root_mean_squared_error: 0.3354
# Epoch 30/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6804 - root_mean_squared_error: 0.3401 - val_loss: 0.6915 - val_root_mean_squared_error: 0.3355
# Epoch 31/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6813 - root_mean_squared_error: 0.3409 - val_loss: 0.6914 - val_root_mean_squared_error: 0.3354
# Epoch 32/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6837 - root_mean_squared_error: 0.3427 - val_loss: 0.6915 - val_root_mean_squared_error: 0.3354
# Epoch 33/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6839 - root_mean_squared_error: 0.3430 - val_loss: 0.6916 - val_root_mean_squared_error: 0.3355
# Epoch 34/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6812 - root_mean_squared_error: 0.3408 - val_loss: 0.6914 - val_root_mean_squared_error: 0.3354
# Epoch 35/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6752 - root_mean_squared_error: 0.3365 - val_loss: 0.6913 - val_root_mean_squared_error: 0.3353
# Epoch 36/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6775 - root_mean_squared_error: 0.3382 - val_loss: 0.6913 - val_root_mean_squared_error: 0.3353
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6809 - root_mean_squared_error: 0.3406 - val_loss: 0.6914 - val_root_mean_squared_error: 0.3354
# Epoch 38/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6770 - root_mean_squared_error: 0.3378 - val_loss: 0.6916 - val_root_mean_squared_error: 0.3355
# Epoch 39/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6753 - root_mean_squared_error: 0.3366 - val_loss: 0.6918 - val_root_mean_squared_error: 0.3357
# Epoch 40/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6739 - root_mean_squared_error: 0.3355 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3358
# Epoch 41/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6763 - root_mean_squared_error: 0.3374 - val_loss: 0.6919 - val_root_mean_squared_error: 0.3357
# Epoch 42/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6725 - root_mean_squared_error: 0.3345 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 43/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6696 - root_mean_squared_error: 0.3323 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3360
# Epoch 44/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6729 - root_mean_squared_error: 0.3350 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3358
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6680 - root_mean_squared_error: 0.3312 - val_loss: 0.6918 - val_root_mean_squared_error: 0.3357
# Epoch 46/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6718 - root_mean_squared_error: 0.3339 - val_loss: 0.6919 - val_root_mean_squared_error: 0.3357
# Epoch 47/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6666 - root_mean_squared_error: 0.3301 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 48/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6658 - root_mean_squared_error: 0.3296 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 49/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6682 - root_mean_squared_error: 0.3314 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6707 - root_mean_squared_error: 0.3332 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3360
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6656 - root_mean_squared_error: 0.3294 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3361
# Epoch 52/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6681 - root_mean_squared_error: 0.3314 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3361
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6676 - root_mean_squared_error: 0.3310 - val_loss: 0.6926 - val_root_mean_squared_error: 0.3362
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6652 - root_mean_squared_error: 0.3292 - val_loss: 0.6928 - val_root_mean_squared_error: 0.3364
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6605 - root_mean_squared_error: 0.3257 - val_loss: 0.6928 - val_root_mean_squared_error: 0.3365
# Epoch 56/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6654 - root_mean_squared_error: 0.3292 - val_loss: 0.6928 - val_root_mean_squared_error: 0.3364
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6646 - root_mean_squared_error: 0.3287 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 58/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6612 - root_mean_squared_error: 0.3261 - val_loss: 0.6934 - val_root_mean_squared_error: 0.3369
# Epoch 59/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6633 - root_mean_squared_error: 0.3278 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6650 - root_mean_squared_error: 0.3291 - val_loss: 0.6928 - val_root_mean_squared_error: 0.3364
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6604 - root_mean_squared_error: 0.3256 - val_loss: 0.6925 - val_root_mean_squared_error: 0.3362
# Epoch 62/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6618 - root_mean_squared_error: 0.3266 - val_loss: 0.6926 - val_root_mean_squared_error: 0.3363
# Epoch 63/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6626 - root_mean_squared_error: 0.3273 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3361
# Epoch 64/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6542 - root_mean_squared_error: 0.3210 - val_loss: 0.6925 - val_root_mean_squared_error: 0.3362
# Epoch 65/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6594 - root_mean_squared_error: 0.3247 - val_loss: 0.6926 - val_root_mean_squared_error: 0.3363
# Epoch 66/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6580 - root_mean_squared_error: 0.3238 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3362
# Epoch 67/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6578 - root_mean_squared_error: 0.3235 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 68/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6576 - root_mean_squared_error: 0.3233 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 69/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6549 - root_mean_squared_error: 0.3214 - val_loss: 0.6920 - val_root_mean_squared_error: 0.3359
# Epoch 70/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6545 - root_mean_squared_error: 0.3210 - val_loss: 0.6921 - val_root_mean_squared_error: 0.3359
# Epoch 71/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6556 - root_mean_squared_error: 0.3220 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 72/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6550 - root_mean_squared_error: 0.3215 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3360
# Epoch 73/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6537 - root_mean_squared_error: 0.3206 - val_loss: 0.6924 - val_root_mean_squared_error: 0.3361
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6528 - root_mean_squared_error: 0.3201 - val_loss: 0.6923 - val_root_mean_squared_error: 0.3361
# Epoch 75/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6534 - root_mean_squared_error: 0.3203 - val_loss: 0.6922 - val_root_mean_squared_error: 0.3360
# Epoch 76/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6533 - root_mean_squared_error: 0.3203 - val_loss: 0.6925 - val_root_mean_squared_error: 0.3362
# Epoch 77/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6523 - root_mean_squared_error: 0.3195 - val_loss: 0.6926 - val_root_mean_squared_error: 0.3363
# Epoch 78/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6515 - root_mean_squared_error: 0.3187 - val_loss: 0.6925 - val_root_mean_squared_error: 0.3362
# Epoch 79/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6500 - root_mean_squared_error: 0.3177 - val_loss: 0.6926 - val_root_mean_squared_error: 0.3363
# Epoch 80/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6551 - root_mean_squared_error: 0.3216 - val_loss: 0.6929 - val_root_mean_squared_error: 0.3365
# Epoch 81/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6518 - root_mean_squared_error: 0.3192 - val_loss: 0.6930 - val_root_mean_squared_error: 0.3366
# Epoch 82/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6518 - root_mean_squared_error: 0.3191 - val_loss: 0.6931 - val_root_mean_squared_error: 0.3366
# Epoch 83/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6485 - root_mean_squared_error: 0.3166 - val_loss: 0.6932 - val_root_mean_squared_error: 0.3367
# Epoch 84/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6495 - root_mean_squared_error: 0.3173 - val_loss: 0.6932 - val_root_mean_squared_error: 0.3367
# Epoch 85/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6511 - root_mean_squared_error: 0.3185 - val_loss: 0.6931 - val_root_mean_squared_error: 0.3366
# Epoch 86/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6487 - root_mean_squared_error: 0.3167 - val_loss: 0.6931 - val_root_mean_squared_error: 0.3367
# Epoch 87/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6500 - root_mean_squared_error: 0.3177 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 88/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6487 - root_mean_squared_error: 0.3165 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 89/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6442 - root_mean_squared_error: 0.3131 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 90/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6459 - root_mean_squared_error: 0.3146 - val_loss: 0.6934 - val_root_mean_squared_error: 0.3369
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6442 - root_mean_squared_error: 0.3134 - val_loss: 0.6933 - val_root_mean_squared_error: 0.3368
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6506 - root_mean_squared_error: 0.3182 - val_loss: 0.6934 - val_root_mean_squared_error: 0.3369
# Epoch 93/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6447 - root_mean_squared_error: 0.3136 - val_loss: 0.6935 - val_root_mean_squared_error: 0.3370
# Epoch 94/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6431 - root_mean_squared_error: 0.3124 - val_loss: 0.6936 - val_root_mean_squared_error: 0.3370
# Epoch 95/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6444 - root_mean_squared_error: 0.3135 - val_loss: 0.6938 - val_root_mean_squared_error: 0.3371
# Epoch 96/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6473 - root_mean_squared_error: 0.3156 - val_loss: 0.6940 - val_root_mean_squared_error: 0.3373
# Epoch 97/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6461 - root_mean_squared_error: 0.3146 - val_loss: 0.6941 - val_root_mean_squared_error: 0.3374
# Epoch 98/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6438 - root_mean_squared_error: 0.3128 - val_loss: 0.6943 - val_root_mean_squared_error: 0.3375
# Epoch 99/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6416 - root_mean_squared_error: 0.3110 - val_loss: 0.6944 - val_root_mean_squared_error: 0.3376
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6444 - root_mean_squared_error: 0.3134 - val_loss: 0.6944 - val_root_mean_squared_error: 0.3376

# %%
# Menampilkan plot loss dan validation

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.ylim(ymin=0, ymax=0.4)
plt.legend(['train', 'test'], loc='center left')
plt.show()

# %%
# Menyiapkan dataframe
place_df = place[['Place_Id','Place_Name','Category','Rating','Price']]
place_df.columns = ['id','place_name','category','rating','price']
df = rating.copy()

# %%
# Mengambil sample user
user_id = df.User_Id.sample(1).iloc[0]
place_visited_by_user = df[df.User_Id == user_id]

# %%
# Membuat data lokasi yang belum dikunjungi user
place_not_visited = place_df[~place_df['id'].isin(place_visited_by_user.Place_Id.values)]['id'] 
place_not_visited = list(
    set(place_not_visited)
    .intersection(set(place_to_place_encoded.keys()))
)
 
place_not_visited = [[place_to_place_encoded.get(x)] for x in place_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_place_array = np.hstack(
    ([[user_encoder]] * len(place_not_visited), place_not_visited)
)

# %%
# Mengambil top 5 recommendation
ratings = model.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-5:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]
 
print('Daftar rekomendasi untuk: {}'.format('User ' + str(user_id)))
print('===' * 5,'\n')
print('----' * 5)
print('Tempat dengan rating wisata paling tinggi dari user')
print('----' * 5)
 
top_place_user = (
    place_visited_by_user.sort_values(
        by = 'Place_Ratings',
        ascending=False
    )
    .head(5)
    .Place_Id.values
)
 
place_df_rows = place_df[place_df['id'].isin(top_place_user)]
for row in place_df_rows.itertuples():
    print(row.place_name, ':', row.category)

print('')
print('----' * 5)
print('Top 5 place recommendation')
print('----' * 5)
 
recommended_place = place_df[place_df['id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.place_name, '\n    ', row.category, ',', 'Harga Tiket Masuk ', row.price, ',', 'Rating Wisata ', row.rating,'\n')

print('==='*5)
# Out:
# Daftar rekomendasi untuk: User 250
# ===============
#
# --------------------
# Tempat dengan rating wisata paling tinggi dari user
# --------------------
# Jalan Braga : Budaya
# Kawah Putih : Cagar Alam
# Kawasan Punclut : Taman Hiburan
# Gunung Papandayan : Cagar Alam
# Lawangwangi Creative Space : Taman Hiburan
#
# --------------------
# Top 5 place recommendation
# --------------------
# 1 . GunungTangkuban perahu
#      Cagar Alam , Harga Tiket Masuk  30000 , Rating Wisata  4.5
#
# 2 . Trans Studio Bandung
#      Taman Hiburan , Harga Tiket Masuk  280000 , Rating Wisata  4.5
#
# 3 . Dusun Bambu
#      Taman Hiburan , Harga Tiket Masuk  25000 , Rating Wisata  4.5
#
# 4 . Dago Dreampark
#      Taman Hiburan , Harga Tiket Masuk  40000 , Rating Wisata  4.2
#
# 5 . Stone Garden Citatah
#      Taman Hiburan , Harga Tiket Masuk  30000 , Rating Wisata  4.4
#
# ===============

# %%
model2.evaluate([x_train[:,0],x_train[:,1]], y_train)
# Out:
# 25/25 [==============================] - 1s 8ms/step - loss: 0.3782 - root_mean_squared_error: 0.0430
# [0.37820544838905334, 0.04303490370512009]

# %%
model2.save('recommendation_rating_model2.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# EXERCISE: Save the trained model as a Keras HDF5 file. 
import time 
saved_model_path = "/tmp/my_model2.h5"

# YOUR CODE HERE
model2.save(saved_model_path)

# %%
# !pip install tensorflowjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.18.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 4.4 MB/s
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Collecting packaging~=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.2 MB/s
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging~=20.9->tensorflowjs) (3.0.9)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.5.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.46.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (4.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.26.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (14.0.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.2.0)
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed packaging-20.9 tensorflowjs-3.18.0

# %%
# EXERCISE: Use the tensorflow.js converter to convert the saved Keras model into JSON format.

# YOUR CODE HERE
# !tensorflowjs_converter --input_format=keras {saved_model_path} ./
